# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ### Loading Data

# %%
pokemon  =pd.read_csv("./pokemon.csv")

# %%
pokemon
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %% [markdown]
# ### Analysing Data

# %%
pokemon.shape
# Out:
# (801, 41)

# %%
co_rel = pokemon.corr()

# %%
co_rel.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_6b957_row0_col0,#T_6b957_row1_col1,#T_6b957_row2_col2,#T_6b957_row3_col3,#T_6b957_row4_col4,#T_6b957_row5_col5,#T_6b957_row6_col6,#T_6b957_row7_col7,#T_6b957_row8_col8,#T_6b957_row9_col9,#T_6b957_row10_col10,#T_6b957_row11_col11,#T_6b957_row12_col12,#T_6b957_row13_col13,#T_6b957_row14_col14,#T_6b957_row15_col15,#T_6b957_row16_col16,#T_6b957_row17_col17,#T_6b957_row18_col18,#T_6b957_row19_col19,#T_6b957_row20_col20,#T_6b957_row21_col21,#T_6b957_row22_col22,#T_6b957_row23_col23,#T_6b957_row24_col24,#T_6b957_row25_col25,#T_6b957_row26_col26,#T_6b957_row27_col27,#T_6b957_row28_col28,#T_6b957_row29_col29,#T_6b957_row30_col30,#T_6b957_row31_col31,#T_6b957_row32_col32,#T_6b957_row33_col33{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_6b957_row0_col1,#T_6b957_row0_col6,#T_6b957_row4_col5,#T_6b957_row4_col7,#T_6b957_row6_col0,#T_6b957_row6_col11,#T_6b957_row16_col11,#T_6b957_row16_col17,#T_6b957_row22_col10{
# ...

# %%
fea = ["attack", "base_egg_steps", "base_total", "defense", "experience_growth", "height_m", "hp", "sp_attack", "sp_defense", "speed", "weight_kg"]

# %%
features = pokemon[fea]

# %%
features.isnull().any()
# Out:
# attack               False
# base_egg_steps       False
# base_total           False
# defense              False
# experience_growth    False
# height_m              True
# hp                   False
# sp_attack            False
# sp_defense           False
# speed                False
# weight_kg             True
# dtype: bool

# %%
features['height_m'].mean()
# Out:
# 1.1638924455825865

# %%
features['weight_kg'].mean()
# Out:
# 61.378104993597944

# %%
features['height_m'] = features['height_m'].fillna(features["height_m"].mean()) 
features['weight_kg'] = features['weight_kg'].fillna(features["weight_kg"].mean())
# Out:
# <ipython-input-12-9720b28addbc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['height_m'] = features['height_m'].fillna(features["height_m"].mean())
# <ipython-input-12-9720b28addbc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['weight_kg'] = features['weight_kg'].fillna(features["weight_kg"].mean())

# %%
features.isnull().any()
# Out:
# attack               False
# base_egg_steps       False
# base_total           False
# defense              False
# experience_growth    False
# height_m             False
# hp                   False
# sp_attack            False
# sp_defense           False
# speed                False
# weight_kg            False
# dtype: bool

# %%
corr_features = features.corr()

# %%
corr_features.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_3fb43_row0_col0,#T_3fb43_row1_col1,#T_3fb43_row2_col2,#T_3fb43_row3_col3,#T_3fb43_row4_col4,#T_3fb43_row5_col5,#T_3fb43_row6_col6,#T_3fb43_row7_col7,#T_3fb43_row8_col8,#T_3fb43_row9_col9,#T_3fb43_row10_col10{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_3fb43_row0_col1{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_3fb43_row0_col2{
#             background-color:  #308cbe;
#             color:  #000000;
#         }#T_3fb43_row0_col3,#T_3fb43_row7_col8{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_3fb43_row0_col4,#T_3fb43_row7_col0{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_3fb43_row0_col5{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_3fb43_row0_col6,#T_3fb43_row3_col0,#T_3fb43_row9_col7{
#             background-color:  #c0c9e2;
# ...

# %%
target = pokemon['is_legendary']

# %%
X_train , X_test , y_train , y_test = train_test_split(features,target,test_size=0.30,random_state= 5)

# %%
tree =DecisionTreeClassifier(random_state=5)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=5)

# %%
predict = tree.predict(X_test)

# %%
accuracy_score(y_true=y_test, y_pred=predict)
# Out:
# 0.983402489626556

# %%
classification_report(y_test, y_pred, target_names=target_names)

# %% [markdown]
# ## Unexpectedly we got really high accuracy
# # Thanks
